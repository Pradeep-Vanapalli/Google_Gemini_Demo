# %%
# !pip install -q -U google-generativeai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.6/146.6 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 598.7/598.7 kB 7.9 MB/s eta 0:00:00

# %% [markdown]
# **Directly via API(Without orechestration framework)**

# %%
import pathlib
import textwrap
import google.generativeai as genai
from IPython.display import display, Markdown

# %%
def to_markdown(text):
  text = text.replace('.','*')
  return Markdown(textwrap.indent(text, '>', predicate=lambda _: True))

# %%
import os
GOOGLE_API_KEY = "AIzaSyC5EUZv4-HxKhwKqSEy7_l8MTpa_y_XS9g"
genai.configure(api_key = GOOGLE_API_KEY)

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
model
# Out:
#  genai.GenerativeModel(
#    model_name='models/gemini-pro',
#    generation_config={}.
#    safety_settings={}
# )

# %%
response = model.generate_content("What is AI")

# %%
response

# %%
response.text
# Out:
# 'Artificial Intelligence (AI) refers to the simulation of human intelligence processes by machines, especially computer systems. It involves the ability of machines to perform tasks that normally require human intelligence, such as reasoning, learning, problem-solving, perception, and language understanding. AI techniques enable computers to learn from data, identify patterns, make decisions, and take actions based on their learning. It involves various subfields, including machine learning, natural language processing, computer vision, robotics, and more.\n\nKey aspects of AI include:\n\n1. **Machine Learning:** AI systems utilize algorithms that can learn from data and improve their performance over time. They can be trained on large datasets to identify patterns, make predictions, and make decisions without explicit programming.\n\n2. **Natural Language Processing:** AI techniques allow computers to understand and generate human language. This includes tasks like sentiment analysi
# ...

# %%
to_markdown(response.text)
# Out:
# >Artificial Intelligence (AI) refers to the simulation of human intelligence processes by machines, especially computer systems* It involves the ability of machines to perform tasks that normally require human intelligence, such as reasoning, learning, problem-solving, perception, and language understanding* AI techniques enable computers to learn from data, identify patterns, make decisions, and take actions based on their learning* It involves various subfields, including machine learning, natural language processing, computer vision, robotics, and more*
# >
# >Key aspects of AI include:
# >
# >1* **Machine Learning:** AI systems utilize algorithms that can learn from data and improve their performance over time* They can be trained on large datasets to identify patterns, make predictions, and make decisions without explicit programming*
# >
# ...

# %% [markdown]
# **Vision Capability**

# %%
import PIL.Image

# %%
img = PIL.Image.open('/content/Screenshot from 2023-12-15 23-00-36.png')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080>

# %%
vision_model = genai.GenerativeModel('gemini-pro-vision')

# %%
response = vision_model.generate_content(img)

# %%
response.text
# Out:
# ' Google API key is a unique identifier that is used to authenticate requests to Google APIs. It is a string of characters that is typically generated by the Google Cloud Platform Console. API keys are used to track and monitor the usage of Google APIs, and to ensure that only authorized users are able to access them.\n\nTo create an API key, you will need to visit the Google Cloud Platform Console and select the project that you want to use the API key for. Once you have selected the project, you will need to click on the "Credentials" tab and then click on the "Create Credentials" button. You will then be able to select the type of credential that you want to create, and you will need to enter the necessary information. Once you have entered the necessary information, you will be able to click on the "Create" button to create the API key.\n\nOnce you have created an API key, you will need to use it to authenticate your requests to Google APIs. To do this, you will need to include t
# ...

# %%
to_markdown(response.text)
# Out:
# > Google API key is a unique identifier that is used to authenticate requests to Google APIs* It is a string of characters that is typically generated by the Google Cloud Platform Console* API keys are used to track and monitor the usage of Google APIs, and to ensure that only authorized users are able to access them*
# >
# >To create an API key, you will need to visit the Google Cloud Platform Console and select the project that you want to use the API key for* Once you have selected the project, you will need to click on the "Credentials" tab and then click on the "Create Credentials" button* You will then be able to select the type of credential that you want to create, and you will need to enter the necessary information* Once you have entered the necessary information, you will be able to click on the "Create" button to create the API key*
# >
# ...

# %%
response = vision_model.generate_content([
    "You are an automated software tester at an IT company. Generate test cases after identifying all the components.",
    img
], stream=True)

response.resolve()
to_markdown(response.text)
# Out:
# > **Component 1: API Key Creation**
# >**Test Case 1:**
# >* **Test Step:** Click on the "Create API Key" button*
# >* **Expected Result:** A modal window should open with a form to create a new API key*
# >
# >**Test Case 2:**
# >* **Test Step:** Enter a name for the API key in the "API Key Name" field*
# >* **Expected Result:** The API key name should be displayed in the "API Key" field*
# >
# >**Test Case 3:**
# >* **Test Step:** Select a project from the "Project" dropdown list*
# >* **Expected Result:** The project name should be displayed in the "Project" field*
# >
# >**Test Case 4:**
# >* **Test Step:** Click on the "Create" button*
# >* **Expected Result:** The API key should be created and displayed in the "API Key" field*
# >
# >**Component 2: API Key Deletion**
# >**Test Case 1:**
# >* **Test Step:** Click on the "Delete" button next to an API key*
# >* **Expected Result:** A confirmation dialog should open*
# >
# >**Test Case 2:**
# ...

# %%
for m in genai.list_models():
  if "generateContent" in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-pro
# models/gemini-pro-vision
